# %%
#Pandas program to compare the elements of two Pandas series.
#Sample Series [4,65,436,3,9], [7,0,3,897,9]

import pandas as pd

a = pd.Series([4,65,436,3,9])
b = pd.Series([7,0,3,897,9])

print("Original Series:")
print(a)
print(b)
print("\nCompare the elements of the said Series:")
print(a == b)

print("\nCheck whether elements of a series are greater than others:")
print(a > b)

print("\nCheck whether elements of a series are less than others:")
print(a < b)

print("\nCheck whether elements of a series are greater than or equal to others:")
print(a >= b)

print("\nCheck whether elements of a series are less than or equal to others:")
print(a <= b)
# Out:
# Original Series:
# 0      4
# 1     65
# 2    436
# 3      3
# 4      9
# dtype: int64
# 0      7
# 1      0
# 2      3
# 3    897
# 4      9
# dtype: int64
#
# Compare the elements of the said Series:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
#
# Check whether elements of a series are greater than others:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool
#
# Check whether elements of a series are less than others:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
#
# Check whether elements of a series are greater than or equal to others:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool
#
# Check whether elements of a series are less than or equal to others:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
# Pandas program to add, subtract, multiply and divide two Pandas series.
# Sample Series: [2,4,6,8,14], [1,3,5,7,9]

import pandas as pd

a = pd.Series([2,4,6,8,14])
b = pd.Series([1,3,5,7,9])

print("Original Series:")
print(a)
print(b)
print("\nAdd two series:")
print(a + b)

print("\nSubtract two series:")
print(a - b)

print("\nMultiply two series:")
print(a * b)

print("\nDivide two series:")
print(a / b)
# Out:
# Original Series:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    14
# dtype: int64
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
#
# Add two series:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtract two series:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiply two series:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Divide two series:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
# Pandas program to convert a dictionary to a Pandas series.
# Sample dictionary: dictionary1 = {‘Josh’: 24, ‘Sam’: 36, ‘Peace’: 19, ‘Charles’: 65, ‘Tom’: 44}

import pandas as
